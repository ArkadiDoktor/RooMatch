# %%
import os
import re
import csv
import random
from pathlib import Path
from typing import Dict, List

import torch
from PIL import Image, ImageDraw
from diffusers import StableDiffusionInpaintPipeline

# %%
ROOM_ATTRIBUTES = {
    "lighting": [
        "change lighting to bright morning daylight coming from the window",
        "change lighting to warm evening indoor light with strong shadows",
        "change lighting to cool artificial night lighting"
    ],
    "rug": [
        "remove any rug from the floor",
        "add a large patterned rug covering the floor",
        "replace the rug with a neutral minimalist rug"
    ],
    "curtains": [
        "fully open the curtains letting light in",
        "close the curtains with thick fabric",
        "replace curtains with half-open blinds"
    ],
    "wall_decor": [
        "remove all wall art",
        "add framed pictures on the walls",
        "add minimal modern wall decorations"
    ],
    "plants": [
        "remove indoor plants",
        "add one large indoor plant",
        "add multiple small plants around the room"
    ],
    "clutter": [
        "make the room very tidy and minimal",
        "add everyday clutter like books and small objects",
        "slightly rearrange small objects on surfaces"
    ],
}

# %%
BASE_PROMPT = (
    "Photorealistic image of the SAME physical room as the input image. "
    "Keep the room geometry, walls, windows, and layout unchanged. "
    "Actively MODIFY decor, lighting, materials, and movable objects. "
    "You MUST introduce visible changes while preserving the same room."
)

NEGATIVE_PROMPT = (
    "different room, new layout, changed geometry, "
    "distorted walls, warped perspective, extra windows, low quality"
)

# %%
def random_inpaint_mask(w: int, h: int) -> Image.Image:
    mask = Image.new("L", (w, h), 0)
    draw = ImageDraw.Draw(mask)

    # large central region
    draw.rectangle(
        [int(w*0.1), int(h*0.1), int(w*0.9), int(h*0.9)],
        fill=255
    )

    # decor-heavy lower regions
    for _ in range(3):
        x0 = random.randint(0, w//2)
        y0 = random.randint(h//3, h-1)
        x1 = x0 + random.randint(w//4, w//2)
        y1 = y0 + random.randint(h//6, h//3)
        draw.rectangle([x0, y0, x1, y1], fill=255)

    return mask.resize((w//2, h//2), Image.BILINEAR).resize((w, h), Image.BILINEAR)

# %%
def generate_attributed_prompt(min_attrs=2, max_attrs=4) -> Dict:
    keys = random.sample(
        list(ROOM_ATTRIBUTES.keys()),
        random.randint(min_attrs, max_attrs)
    )

    actions = [random.choice(ROOM_ATTRIBUTES[k]) for k in keys]

    prompt = (
        BASE_PROMPT
        + " Apply the following changes: "
        + "; ".join(actions)
        + ". High realism, straight lines."
    )

    return {
        "prompt": prompt,
        "negative_prompt": NEGATIVE_PROMPT,
        "attributes": dict(zip(keys, actions))
    }

# %%
@torch.inference_mode()
def generate_room_variants(
    pipe,
    image: Image.Image,
    num_variants: int = 10,
    seed: int = 0,
    size: int = 512
) -> List[Dict]:

    image = image.convert("RGB").resize((size, size), Image.LANCZOS)
    w, h = image.size

    results = []
    generator = torch.Generator(device=pipe.device)

    for i in range(num_variants):
        meta = generate_attributed_prompt()
        mask = random_inpaint_mask(w, h)

        generator.manual_seed(seed + i)

        out = pipe(
            prompt=meta["prompt"],
            negative_prompt=meta["negative_prompt"],
            image=image,
            mask_image=mask,
            guidance_scale=7.5,
            num_inference_steps=35,
            strength=0.8,
            generator=generator,
        ).images[0]

        results.append({
            "image": out,
            "attributes": meta["attributes"],
            "seed": seed + i
        })

    return results

# %%
def build_dataset(
    input_dir: str,
    output_dir: str,
    num_variants: int = 10
):
    device = "cuda" if torch.cuda.is_available() else "cpu"

    pipe = StableDiffusionInpaintPipeline.from_pretrained(
        "runwayml/stable-diffusion-inpainting",
        torch_dtype=torch.float16 if device == "cuda" else torch.float32,
        safety_checker=None
    ).to(device)

    pipe.enable_attention_slicing()

    input_dir = Path(input_dir)
    output_dir = Path(output_dir)
    real_dir = output_dir / "real"
    synth_dir = output_dir / "synthetic"

    real_dir.mkdir(parents=True, exist_ok=True)
    synth_dir.mkdir(parents=True, exist_ok=True)

    rows = []

    for img_path in sorted(input_dir.glob("room_*.jpeg")):
        room_id = int(re.search(r"room_(\d+)", img_path.stem).group(1))
        print(f"Processing room {room_id}")

        image = Image.open(img_path)
        real_path = real_dir / img_path.name
        image.save(real_path)

        rows.append({"path": str(real_path), "room_id": room_id, "is_synthetic": 0})

        variants = generate_room_variants(
            pipe=pipe,
            image=image,
            num_variants=num_variants,
            seed=room_id * 1000
        )

        room_out = synth_dir / f"room_{room_id}"
        room_out.mkdir(parents=True, exist_ok=True)

        for i, v in enumerate(variants):
            out_path = room_out / f"syn_{i:02d}.png"
            v["image"].save(out_path)
            rows.append({"path": str(out_path), "room_id": room_id, "is_synthetic": 1})

    with open(output_dir / "labels.csv", "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=["path", "room_id", "is_synthetic"])
        writer.writeheader()
        writer.writerows(rows)

    print("\nDataset generation complete.")

# %%
build_dataset(
    input_dir="/content/input_rooms",
    output_dir="/content/dataset",
    num_variants=10
)
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion_inpaint.StableDiffusionInpaintPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Token indices sequence length is longer than the specified maximum sequence length for this model (81 > 77). Running this sequence through the model will result in indexing errors
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', straight lines .']
# Processing room 1
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['clutter like books and small objects . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['walls . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['; replace curtains with half - open blinds ; add minimal modern wall decorations . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['coming from the window . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['close the curtains with thick fabric . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['.']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['the floor ; fully open the curtains letting light in . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['high realism , straight lines .']
# Processing room 10
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['with a neutral minimalist rug . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['with half - open blinds ; add one large indoor plant . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['curtains letting light in ; remove all wall art . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['the floor ; change lighting to warm evening indoor light with strong shadows . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['covering the floor ; add framed pictures on the walls . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['with thick fabric ; remove all wall art . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artificial night lighting ; fully open the curtains letting light in . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['remove any rug from the floor ; remove all wall art . high realism , straight lines .']
# Processing room 11
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['floor . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['; remove all wall art ; make the room very tidy and minimal . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['. high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['. high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artificial night lighting ; remove indoor plants . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['with half - open blinds ; remove indoor plants . high realism , straight lines .']
#   0%|          | 0/28 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3182025602.py in <cell line: 0>()
# ----> 1 build_dataset(
#       2     input_dir="/content/input_rooms",
#       3     output_dir="/content/dataset",
#       4     num_variants=10
#       5 )
#
# /tmp/ipython-input-192630589.py in build_dataset(input_dir, output_dir, num_variants)
#      34         rows.append({"path": str(real_path), "room_id": room_id, "is_synthetic": 0})
#      35
# ---> 36         variants = generate_room_variants(
#      37             pipe=pipe,
#      38             image=image,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /tmp/ipython-input-801649745.py in generate_room_variants(pipe, image, num_variants, seed, size)
#      20         generator.manual_seed(seed + i)
#      21
# ---> 22         out = pipe(
#      23             prompt=meta["prompt"],
#      24             negative_prompt=meta["negative_prompt"],
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion_inpaint.py in __call__(self, prompt, image, mask_image, masked_image_latents, height, width, padding_mask_crop, strength, num_inference_steps, timesteps, sigmas, guidance_scale, negative_prompt, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, output_type, return_dict, cross_attention_kwargs, clip_skip, callback_on_step_end, callback_on_step_end_tensor_inputs, **kwargs)
#    1287         mask, masked_image_latents = self.prepare_mask_latents(
#    1288             mask_condition,
# -> 1289             masked_image,
#    1290             batch_size * num_images_per_prompt,
#    1291             height,
#
# /usr/local/lib/python3.12/dist-packages/diffusers/schedulers/scheduling_ddim.py in step(self, model_output, timestep, sample, eta, use_clipped_model_output, generator, variance_noise, return_dict)
#     442         if use_clipped_model_output:
#     443             # the pred_epsilon is always re-derived from the clipped x_0 in Glide
# --> 444             pred_epsilon = (sample - alpha_prod_t ** (0.5) * pred_original_sample) / beta_prod_t ** (0.5)
#     445
#     446         # 6. compute "direction pointing to x_t" of formula (12) from https://arxiv.org/pdf/2010.02502.pdf
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in wrapped(self, *args, **kwargs)
#      36     f: Callable[Concatenate[_TensorLike, _P], "Tensor"],
#      37 ) -> Callable[Concatenate[_TensorLike, _P], "Tensor"]:
# ---> 38     @functools.wraps(f)
#      39     def wrapped(self: _TensorLike, *args: _P.args, **kwargs: _P.kwargs) -> "Tensor":
#      40         try:
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r dataset.zip dataset/
# Out:
#   adding: dataset/ (stored 0%)
#   adding: dataset/real/ (stored 0%)
#   adding: dataset/real/room_20.jpg (deflated 3%)
#   adding: dataset/real/room_4.jpg (deflated 1%)
#   adding: dataset/real/room_39.jpg (deflated 1%)
#   adding: dataset/real/room_34.jpg (deflated 6%)
#   adding: dataset/real/room_19.jpg (deflated 1%)
#   adding: dataset/real/room_45.jpg (deflated 3%)
#   adding: dataset/real/room_27.jpg (deflated 2%)
#   adding: dataset/real/room_38.jpg (deflated 1%)
#   adding: dataset/real/room_29.jpg (deflated 1%)
#   adding: dataset/real/room_23.jpg (deflated 1%)
#   adding: dataset/real/room_26.jpg (deflated 1%)
#   adding: dataset/real/room_13.jpg (deflated 1%)
#   adding: dataset/real/room_2.jpg (deflated 3%)
#   adding: dataset/real/room_49.jpg (deflated 1%)
#   adding: dataset/real/room_12.jpg (deflated 1%)
#   adding: dataset/real/room_42.jpg (deflated 2%)
#   adding: dataset/real/room_46.jpg (deflated 1%)
#   adding: dataset/real/room_40.jpg (deflated 1%)
#   adding: dataset/real/room_17.jpg (deflated 1%)
#   adding: dataset/real/room_28.jpg (deflated 2%)
#   adding: dataset/real/room_33.jpg (deflated 3%)
#   adding: dataset/real/room_22.jpg (deflated 1%)
#   adding: dataset/real/room_37.jpg (deflated 1%)
#   adding: dataset/real/room_18.jpg (deflated 4%)
#   adding: dataset/real/room_47.jpg (deflated 3%)
#   adding: dataset/real/room_0.jpg (deflated 2%)
#   adding: dataset/real/room_41.jpg (deflated 1%)
#   adding: dataset/real/room_25.jpg (deflated 1%)
#   adding: dataset/real/room_8.jpg (deflated 3%)
#   adding: dataset/real/room_44.jpg (deflated 2%)
#   adding: dataset/real/room_36.jpg (deflated 1%)
#   adding: dataset/real/.ipynb_checkpoints/ (stored 0%)
#   adding: dataset/real/room_43.jpg (deflated 1%)
#   adding: dataset/real/room_24.jpg (deflated 1%)
#   adding: dataset/real/room_16.jpg (deflated 2%)
#   adding: dataset/real/room_48.jpg (deflated 4%)
#   adding: dataset/real/room_6.jpg (deflated 3%)
#   adding: dataset/real/room_31.jpg (deflated 3%)
#   adding: dataset/real/room_9.jpg (deflated 1%)
#   adding: dataset/real/room_21.jpg (deflated 5%)
#   adding: dataset/real/room_32.jpg (deflated 2%)
#   adding: dataset/real/room_14.jpg (deflated 1%)
#   adding: dataset/real/room_30.jpg (deflated 1%)
#   adding: dataset/real/room_7.jpg (deflated 1%)
#   adding: dataset/synthetic/ (stored 0%)
#   adding: dataset/synthetic/room_47/ (stored 0%)
#   adding: dataset/synthetic/room_47/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_47/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_23/ (stored 0%)
#   adding: dataset/synthetic/room_23/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_23/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_13/ (stored 0%)
#   adding: dataset/synthetic/room_13/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_13/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_32/ (stored 0%)
#   adding: dataset/synthetic/room_32/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_32/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_33/ (stored 0%)
#   adding: dataset/synthetic/room_33/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_33/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_0/ (stored 0%)
#   adding: dataset/synthetic/room_0/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_0/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_9/ (stored 0%)
#   adding: dataset/synthetic/room_9/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_9/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_46/ (stored 0%)
#   adding: dataset/synthetic/room_46/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_46/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_22/ (stored 0%)
#   adding: dataset/synthetic/room_22/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_22/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_12/ (stored 0%)
#   adding: dataset/synthetic/room_12/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_12/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_17/ (stored 0%)
#   adding: dataset/synthetic/room_17/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_17/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_24/ (stored 0%)
#   adding: dataset/synthetic/room_24/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_24/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_37/ (stored 0%)
#   adding: dataset/synthetic/room_37/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_37/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_40/ (stored 0%)
#   adding: dataset/synthetic/room_40/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_40/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_29/ (stored 0%)
#   adding: dataset/synthetic/room_29/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_29/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_25/ (stored 0%)
#   adding: dataset/synthetic/room_25/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_25/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_36/ (stored 0%)
#   adding: dataset/synthetic/room_36/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_36/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_2/ (stored 0%)
#   adding: dataset/synthetic/room_2/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_2/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_28/ (stored 0%)
#   adding: dataset/synthetic/room_28/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_28/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_48/ (stored 0%)
#   adding: dataset/synthetic/room_48/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_48/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_45/ (stored 0%)
#   adding: dataset/synthetic/room_45/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_45/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_30/ (stored 0%)
#   adding: dataset/synthetic/room_30/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_30/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_6/ (stored 0%)
#   adding: dataset/synthetic/room_6/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_6/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_16/ (stored 0%)
#   adding: dataset/synthetic/room_16/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_16/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_38/ (stored 0%)
#   adding: dataset/synthetic/room_38/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_38/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_21/ (stored 0%)
#   adding: dataset/synthetic/room_21/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_21/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_26/ (stored 0%)
#   adding: dataset/synthetic/room_26/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_26/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_41/ (stored 0%)
#   adding: dataset/synthetic/room_41/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_41/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_39/ (stored 0%)
#   adding: dataset/synthetic/room_39/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_39/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_4/ (stored 0%)
#   adding: dataset/synthetic/room_4/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_4/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_20/ (stored 0%)
#   adding: dataset/synthetic/room_20/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_20/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_27/ (stored 0%)
#   adding: dataset/synthetic/room_27/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_27/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_44/ (stored 0%)
#   adding: dataset/synthetic/room_44/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_44/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_49/ (stored 0%)
#   adding: dataset/synthetic/room_49/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_49/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_14/ (stored 0%)
#   adding: dataset/synthetic/room_14/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_14/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_34/ (stored 0%)
#   adding: dataset/synthetic/room_34/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_34/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_18/ (stored 0%)
#   adding: dataset/synthetic/room_18/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_18/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_10/ (stored 0%)
#   adding: dataset/synthetic/room_10/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_10/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_7/ (stored 0%)
#   adding: dataset/synthetic/room_7/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_7/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_43/ (stored 0%)
#   adding: dataset/synthetic/room_43/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_43/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_8/ (stored 0%)
#   adding: dataset/synthetic/room_8/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_8/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_1/ (stored 0%)
#   adding: dataset/synthetic/room_1/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_1/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_42/ (stored 0%)
#   adding: dataset/synthetic/room_42/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_42/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_31/ (stored 0%)
#   adding: dataset/synthetic/room_31/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_31/syn_00.png (deflated 0%)
#   adding: dataset/synthetic/room_19/ (stored 0%)
#   adding: dataset/synthetic/room_19/syn_02.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_06.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_01.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_08.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_04.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_03.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_09.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_07.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_05.png (deflated 0%)
#   adding: dataset/synthetic/room_19/syn_00.png (deflated 0%)
#   adding: dataset/labels.csv (deflated 94%)
